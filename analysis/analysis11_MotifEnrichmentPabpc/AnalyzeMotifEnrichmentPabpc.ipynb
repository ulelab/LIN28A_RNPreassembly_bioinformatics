# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
import sys
from sklearn.preprocessing import StandardScaler

scriptpath = "../../src/"
sys.path.append(os.path.abspath(scriptpath))
import KmerGroups as kg
import PekaLib as peka

# %%
# Import PEKA results for PABPC data
PekaFiles = sorted(glob('../../data/Pabpc1Pabpc4Iclip_2022/PEKA/*.tsv')) + sorted(glob('../../results/20221006_Pabpc1Peka/PekaOutput/*DKO_*5mer_distribution_UTR3.tsv'))

# Save to
outpath = '../../results/AnalyzeMotifEnrichmentForPabpc'
os.makedirs(outpath, exist_ok=True)

# %%
PekaFiles
# Out:
# ['../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C1_Crick1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C1_Crick2_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C1_Crick1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C1_Crick2_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv',
#  '../../data/Pabpc1Pabpc4Iclip_2022/PEKA/KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv',
#  '../../results/20221006_Pabpc1Peka/PekaOutput/PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_5mer_distribution_UTR3.tsv',
#  '../../results/20221006_Pabpc1Peka/PekaOutput/PABPC1_ESC_DKO_nodox_grouped_cdna_mm39_5mer_distribution_UTR3.tsv']

# %%
DfScores = peka.GetPEKAScoresFromTsv(PekaFiles).fillna(0)

# %%
scaler = StandardScaler()
scaler.fit(DfScores)
DfZScores = pd.DataFrame(scaler.transform(DfScores), columns = DfScores.columns, index = DfScores.index)

# %%
DfZScores.head()
# Out:
#        DOX_C1_Crick1_5mer_distribution_UTR3.tsv  \
# AAAAA                                  2.094780
# AAAAC                                  0.137025
# AAAAG                                  0.539800
# AAAAU                                  1.158912
# AAACA                                 -0.181649
#
#        DOX_C1_Crick2_5mer_distribution_UTR3.tsv  \
# AAAAA                                  1.588490
# AAAAC                                  0.102073
# AAAAG                                  0.556875
# AAAAU                                  1.214424
# AAACA                                 -0.132001
#
#        DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv  \
# AAAAA                                     1.631698
# AAAAC                                     0.014804
# AAAAG                                     0.209895
# AAAAU                                     0.241847
# AAACA                                    -0.074984
#
#        DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv  \
# AAAAA                                     5.029149
# AAAAC                                     1.275166
# AAAAG                                     1.480854
# AAAAU                                     1.717267
# AAACA                                     0.599537
#
#        DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv  \
# AAAAA                                         5.636160
# AAAAC                                         1.885248
# AAAAG                                         1.913065
# AAAAU                                         3.649528
# AAACA                                         1.214181
#
#        DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv  \
# AAAAA                                         6.611464
# AAAAC                                         1.705517
# AAAAG                                         2.027775
# AAAAU                                         4.150617
# AAACA                                         1.453143
#
#        KO_C1_Crick1_5mer_distribution_UTR3.tsv  \
# AAAAA                                 2.320322
# AAAAC                                 0.217153
# AAAAG                                 0.693355
# AAAAU                                 1.115074
# AAACA                                -0.114608
#
#        KO_C1_Crick2_5mer_distribution_UTR3.tsv  \
# AAAAA                                 2.269072
# AAAAC                                 0.412390
# AAAAG                                 0.758149
# AAAAU                                 1.659169
# AAACA                                 0.073700
#
#        KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv  \
# AAAAA                                    2.814411
# AAAAC                                    0.715174
# AAAAG                                    0.743032
# AAAAU                                    1.022811
# AAACA                                   -0.007922
#
#        KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv  \
# AAAAA                                    2.990567
# AAAAC                                    0.877101
# AAAAG                                    0.513984
# AAAAU                                    0.833187
# AAACA                                   -0.171973
#
#        KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv  \
# AAAAA                                        6.955714
# AAAAC                                        2.042875
# AAAAG                                        2.366353
# AAAAU                                        4.256737
# AAACA                                        1.330838
#
#        KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv  \
# AAAAA                                        5.366480
# AAAAC                                        1.460159
# AAAAG                                        1.764037
# AAAAU                                        2.953131
# AAACA                                        0.973600
#
#        PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_5mer_distribution_UTR3.tsv  \
# AAAAA                                           2.414184
# AAAAC                                           0.674361
# AAAAG                                           1.227563
# AAAAU                                           0.932770
# AAACA                                           0.608877
#
#        PABPC1_ESC_DKO_nodox_grouped_cdna_mm39_5mer_distribution_UTR3.tsv
# AAAAA                                           1.535461
# AAAAC                                           0.537150
# AAAAG                                           0.719771
# AAAAU                                           0.890861
# AAACA                                           0.200351

# %%
SignificantKmersDict = peka.GetSignificantKmersFileList(PekaFiles)

# %%
SignificantKmersDict
# Out:
# {'DOX_C1_Crick1_5mer_distribution_UTR3.tsv': ['AAUUU',
#   'ACUUU',
#   'AUAUU',
#   'AUUUA',
#   'AUUUC',
#   'AUUUU',
#   'CAUUU',
#   'CUUUA',
#   'CUUUU',
#   'GAUUU',
#   'GGUUU',
#   'GUAUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCAUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAUA',
#   'UUAUU',
#   'UUCAU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAC',
#   'UUUAU',
#   'UUUCA',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'DOX_C1_Crick2_5mer_distribution_UTR3.tsv': ['AAUUU',
#   'AUAUU',
#   'AUUAU',
#   'AUUUA',
#   'AUUUC',
#   'AUUUU',
#   'CAUUU',
#   'CUUUA',
#   'CUUUU',
#   'GAUUU',
#   'GGUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCAUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUC',
#   'UUAUU',
#   'UUCAU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAC',
#   'UUUAU',
#   'UUUCA',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv': ['AAUUU',
#   'AUUUU',
#   'CAUUU',
#   'CCUUU',
#   'CUUUU',
#   'GAUUU',
#   'GGUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUUU',
#   'UUAAU',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCC',
#   'UUUCU',
#   'UUUGG',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAUAA',
#   'AAUUU',
#   'AUAAA',
#   'AUUUU',
#   'CUUUU',
#   'GGGGG',
#   'GUUUU',
#   'UAAAA',
#   'UAAUA',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAAAU',
#   'AAAUA',
#   'AAUAA',
#   'AAUUU',
#   'AUAAA',
#   'AUAAU',
#   'AUUUU',
#   'CUUUU',
#   'GAAAA',
#   'GUUUU',
#   'UAAAA',
#   'UAAAG',
#   'UAAAU',
#   'UAAUA',
#   'UAAUU',
#   'UAUAA',
#   'UAUUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAAAU',
#   'AAAUA',
#   'AAUAA',
#   'AAUUU',
#   'AUAAA',
#   'AUUUU',
#   'CUUUU',
#   'GAAAA',
#   'GUUUU',
#   'UAAAA',
#   'UAAAG',
#   'UAAAU',
#   'UAAUA',
#   'UAUAA',
#   'UAUUU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C1_Crick1_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAUUU',
#   'ACUUU',
#   'AUAUU',
#   'AUUUC',
#   'AUUUU',
#   'CAUUU',
#   'CUUUU',
#   'GAUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCAUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCA',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C1_Crick2_5mer_distribution_UTR3.tsv': ['AAUUU',
#   'AUAUU',
#   'AUUUU',
#   'CAUUU',
#   'CUUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCA',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAUAA',
#   'AAUUU',
#   'AUUUU',
#   'CUUUU',
#   'GGGGG',
#   'GGUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGGGG',
#   'UGUUU',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGG',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAUAA',
#   'AAUUU',
#   'ACGCA',
#   'AUUUU',
#   'CCUUU',
#   'CGCAU',
#   'CUUUU',
#   'GGGGG',
#   'GGGGU',
#   'GGGUU',
#   'GGUUU',
#   'GUGGG',
#   'GUUUU',
#   'UAAAA',
#   'UAAUU',
#   'UACGC',
#   'UAUUU',
#   'UCUUU',
#   'UGGGG',
#   'UGUUU',
#   'UUAUU',
#   'UUCUU',
#   'UUGGG',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGG',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAAAG',
#   'AAAAU',
#   'AAAUA',
#   'AAUAA',
#   'AAUUU',
#   'AGAAA',
#   'AUAAA',
#   'AUUUU',
#   'CAAAA',
#   'CUUUU',
#   'GAAAA',
#   'GUUUU',
#   'UAAAA',
#   'UAAAG',
#   'UAAAU',
#   'UAAUA',
#   'UAAUU',
#   'UAUAA',
#   'UAUUU',
#   'UCUUU',
#   'UGUAU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAAAU',
#   'AAAUA',
#   'AAUAA',
#   'AAUUU',
#   'AUAAA',
#   'AUUUU',
#   'CUUUU',
#   'GUUUU',
#   'UAAAA',
#   'UAAAG',
#   'UAAUA',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUA',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_5mer_distribution_UTR3.tsv': ['AAAAA',
#   'AAUUU',
#   'AGUUU',
#   'AUUUA',
#   'AUUUU',
#   'CUUUU',
#   'GAUUU',
#   'GGUUU',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUA',
#   'UUAUU',
#   'UUCUU',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU'],
#  'PABPC1_ESC_DKO_nodox_grouped_cdna_mm39_5mer_distribution_UTR3.tsv': ['AAUUU',
#   'AGUUU',
#   'AUGUU',
#   'AUUUU',
#   'CUUUU',
#   'GGUUU',
#   'GUUAU',
#   'GUUUG',
#   'GUUUU',
#   'UAAUU',
#   'UAUUU',
#   'UCUUU',
#   'UGUUA',
#   'UGUUU',
#   'UUAAA',
#   'UUAAU',
#   'UUAUU',
#   'UUCUU',
#   'UUGUU',
#   'UUUAA',
#   'UUUAU',
#   'UUUCU',
#   'UUUGU',
#   'UUUUA',
#   'UUUUC',
#   'UUUUG',
#   'UUUUU']}

# %%
AllSigKmers = []
for kmers in SignificantKmersDict.values():
    AllSigKmers.extend([ k for k in kmers if k not in AllSigKmers])
AllSigKmers = sorted(set(AllSigKmers))

# %%
len(AllSigKmers)
# Out:
# 71

# %% [markdown]
# # Compare significant k-mers between KO and DOX for PABPC1 and PABPC4
# Combine all significant k-mers and cluster them into groups. Then compare z-cores in each group of k-mers across samples

# %%
DfSigKmers = DfZScores.loc[AllSigKmers]
DfSigKmers.columns = [x.split('_5mer_dist')[0] for x in DfSigKmers.columns]
DfSigKmersMelt = DfSigKmers.melt(var_name='File', value_name='z-score')
DfSigKmersMelt['Sample'] = DfSigKmersMelt.File.apply(lambda x: x.split('_5mer_distribution')[0])

# %%
orderCond = ['DOX', 'KO']
orderProt = ['C1', 'C4_Proteintech', 'C4_Benthyl']
colOrd = []
for p in orderProt:
    cols = sorted([x for x in DfSigKmers.columns if p in x])
    colOrd.extend(cols)
DfSigKmers = DfSigKmers[colOrd]

# %%
DfSigKmers.head()
# Out:
#        DOX_C1_Crick1  DOX_C1_Crick2  KO_C1_Crick1  KO_C1_Crick2  \
# AAAAA       2.094780       1.588490      2.320322      2.269072
# AAAAG       0.539800       0.556875      0.693355      0.758149
# AAAAU       1.158912       1.214424      1.115074      1.659169
# AAAUA       0.819424       0.621151      1.046724      1.437571
# AAUAA       0.572083       0.282999      0.697316      1.859601
#
#        PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39  \
# AAAAA                                       2.414184
# AAAAG                                       1.227563
# AAAAU                                       0.932770
# AAAUA                                       0.907226
# AAUAA                                       0.769260
#
#        PABPC1_ESC_DKO_nodox_grouped_cdna_mm39  DOX_C4_Proteintech_1  \
# AAAAA                                1.535461              5.636160
# AAAAG                                0.719771              1.913065
# AAAAU                                0.890861              3.649528
# AAAUA                                0.973569              4.629317
# AAUAA                                0.796604              6.391750
#
#        DOX_C4_Proteintech_2  KO_C4_Proteintech_1  KO_C4_Proteintech_2  \
# AAAAA              6.611464             6.955714             5.366480
# AAAAG              2.027775             2.366353             1.764037
# AAAAU              4.150617             4.256737             2.953131
# AAAUA              4.471940             4.292204             3.219167
# AAUAA              6.917177             5.756443             4.470885
#
#        DOX_C4_Benthyl_1  DOX_C4_Benthyl_2  KO_C4_Benthyl_1  KO_C4_Benthyl_2
# AAAAA          1.631698          5.029149         2.814411         2.990567
# AAAAG          0.209895          1.480854         0.743032         0.513984
# AAAAU          0.241847          1.717267         1.022811         0.833187
# AAAUA          0.089294          2.049648         1.079876         1.418456
# AAUAA         -0.008704          3.931637         2.447679         2.628452

# %%
fig = sns.clustermap(DfSigKmers, col_cluster=False)
fig.savefig(f'{outpath}/ZScoreHeatmap_NaNToZero.pdf', bbox_inches='tight')

# %%
dfPlot = DfScores.copy()
dfPlot.columns = [x.split('_5mer_dist')[0] for x in dfPlot.columns]
dfPlot = dfPlot.loc[AllSigKmers, colOrd]

sns.clustermap(dfPlot, col_cluster=False)

# %% [markdown]
# ## Count A-rich and U-rich significant k-mers in each sample and plot counts

# %%
rows = []
for k, vals in SignificantKmersDict.items():
    a_rich = []
    u_rich = []
    for v in vals:
        if list(v).count('A') >= 3:
            a_rich.append(v)
        elif list(v).count('U') >= 3:
            u_rich.append(v)
        else:
            pass
    # print(k)
    # print(a_rich)
    # print(u_rich)
    row = [k, len(a_rich), len(u_rich), len(vals)]
    rows.append(row)
DfCountGroups = pd.DataFrame(rows, columns=['File', 'A-rich', 'U-rich', 'N significant total'])

# %%
DfCountGroups = DfCountGroups.melt(var_name='Kmer group', value_name='N Significant kmers', id_vars=['File', 'N significant total'])
DfCountGroups['% significant k-mers'] = DfCountGroups['N Significant kmers'].divide(DfCountGroups['N significant total'], axis='index') * 100
DfCountGroups['Sample'] = DfCountGroups['File'].apply(lambda x: x.split('_5mer_')[0])
DfCountGroups['Condition'] = DfCountGroups['File'].apply(lambda x: x.split('_')[0] if x.split('_')[0] in ['KO', 'DOX'] else '.')
DfCountGroups['Experiment'] = DfCountGroups['Sample'].apply(lambda x: x.strip('12_DOXKO'))

# %%
DfCountGroups
# Out:
#                                                  File  N significant total  \
# 0            DOX_C1_Crick1_5mer_distribution_UTR3.tsv                   35
# 1            DOX_C1_Crick2_5mer_distribution_UTR3.tsv                   37
# 2         DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   27
# 3         DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   28
# 4     DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   36
# 5     DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   30
# 6             KO_C1_Crick1_5mer_distribution_UTR3.tsv                   32
# 7             KO_C1_Crick2_5mer_distribution_UTR3.tsv                   27
# 8          KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   26
# 9          KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   35
# 10     KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   38
# 11     KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   31
# 12  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_...                   27
# 13  PABPC1_ESC_DKO_nodox_grouped_cdna_mm39_5mer_di...                   27
# 14           DOX_C1_Crick1_5mer_distribution_UTR3.tsv                   35
# 15           DOX_C1_Crick2_5mer_distribution_UTR3.tsv                   37
# 16        DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   27
# 17        DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   28
# 18    DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   36
# 19    DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   30
# 20            KO_C1_Crick1_5mer_distribution_UTR3.tsv                   32
# 21            KO_C1_Crick2_5mer_distribution_UTR3.tsv                   27
# 22         KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   26
# 23         KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   35
# 24     KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   38
# 25     KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   31
# 26  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_...                   27
# 27  PABPC1_ESC_DKO_nodox_grouped_cdna_mm39_5mer_di...                   27
#
#    Kmer group  N Significant kmers  % significant k-mers  \
# 0      A-rich                    0              0.000000
# 1      A-rich                    1              2.702703
# 2      A-rich                    0              0.000000
# 3      A-rich                    6             21.428571
# 4      A-rich                   13             36.111111
# 5      A-rich                   12             40.000000
# 6      A-rich                    2              6.250000
# 7      A-rich                    1              3.703704
# 8      A-rich                    2              7.692308
# 9      A-rich                    3              8.571429
# 10     A-rich                   15             39.473684
# 11     A-rich                    9             29.032258
# 12     A-rich                    2              7.407407
# 13     A-rich                    1              3.703704
# 14     U-rich                   35            100.000000
# 15     U-rich                   36             97.297297
# 16     U-rich                   27            100.000000
# 17     U-rich                   21             75.000000
# 18     U-rich                   23             63.888889
# 19     U-rich                   18             60.000000
# 20     U-rich                   30             93.750000
# 21     U-rich                   26             96.296296
# 22     U-rich                   22             84.615385
# 23     U-rich                   23             65.714286
# 24     U-rich                   23             60.526316
# 25     U-rich                   22             70.967742
# 26     U-rich                   25             92.592593
# 27     U-rich                   26             96.296296
#
#                                            Sample Condition  \
# 0                                   DOX_C1_Crick1       DOX
# 1                                   DOX_C1_Crick2       DOX
# 2                                DOX_C4_Benthyl_1       DOX
# 3                                DOX_C4_Benthyl_2       DOX
# 4                            DOX_C4_Proteintech_1       DOX
# 5                            DOX_C4_Proteintech_2       DOX
# 6                                    KO_C1_Crick1        KO
# 7                                    KO_C1_Crick2        KO
# 8                                 KO_C4_Benthyl_1        KO
# 9                                 KO_C4_Benthyl_2        KO
# 10                            KO_C4_Proteintech_1        KO
# 11                            KO_C4_Proteintech_2        KO
# 12  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39         .
# 13         PABPC1_ESC_DKO_nodox_grouped_cdna_mm39         .
# 14                                  DOX_C1_Crick1       DOX
# 15                                  DOX_C1_Crick2       DOX
# 16                               DOX_C4_Benthyl_1       DOX
# 17                               DOX_C4_Benthyl_2       DOX
# 18                           DOX_C4_Proteintech_1       DOX
# 19                           DOX_C4_Proteintech_2       DOX
# 20                                   KO_C1_Crick1        KO
# 21                                   KO_C1_Crick2        KO
# 22                                KO_C4_Benthyl_1        KO
# 23                                KO_C4_Benthyl_2        KO
# 24                            KO_C4_Proteintech_1        KO
# 25                            KO_C4_Proteintech_2        KO
# 26  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39         .
# 27         PABPC1_ESC_DKO_nodox_grouped_cdna_mm39         .
#
#                                        Experiment
# 0                                        C1_Crick
# 1                                        C1_Crick
# 2                                      C4_Benthyl
# 3                                      C4_Benthyl
# 4                                  C4_Proteintech
# 5                                  C4_Proteintech
# 6                                        C1_Crick
# 7                                        C1_Crick
# 8                                      C4_Benthyl
# 9                                      C4_Benthyl
# 10                                 C4_Proteintech
# 11                                 C4_Proteintech
# 12  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39
# 13         PABPC1_ESC_DKO_nodox_grouped_cdna_mm39
# 14                                       C1_Crick
# 15                                       C1_Crick
# 16                                     C4_Benthyl
# 17                                     C4_Benthyl
# 18                                 C4_Proteintech
# 19                                 C4_Proteintech
# 20                                       C1_Crick
# 21                                       C1_Crick
# 22                                     C4_Benthyl
# 23                                     C4_Benthyl
# 24                                 C4_Proteintech
# 25                                 C4_Proteintech
# 26  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39
# 27         PABPC1_ESC_DKO_nodox_grouped_cdna_mm39

# %%
DfCountGroups.loc[DfCountGroups.Sample == 'PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39', 'Condition'] = 'DOX'
DfCountGroups.loc[DfCountGroups.Sample == 'PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39', 'Experiment'] = '2iL PABPC1'

DfCountGroups.loc[DfCountGroups.Sample == 'PABPC1_ESC_DKO_nodox_grouped_cdna_mm39', 'Condition'] = 'KO'
DfCountGroups.loc[DfCountGroups.Sample == 'PABPC1_ESC_DKO_nodox_grouped_cdna_mm39', 'Experiment'] = '2iL PABPC1'

# %%
sns.set_style('whitegrid')
fig = sns.catplot(
    data=DfCountGroups, x='Condition', y='N Significant kmers', hue='Kmer group', col='Experiment', kind='bar', col_order=['C1_Crick', '2iL PABPC1', 'C4_Benthyl', 'C4_Proteintech']
)
fig.savefig(f'{outpath}/n_SignificantKmers.pdf', bbox_inches='tight')

# %%
sns.set_style('whitegrid')
fig = sns.catplot(
    data=DfCountGroups, x='Condition', y='% significant k-mers', hue='Kmer group', col='Experiment', kind='bar', order=['DOX', 'KO'], col_order=['C1_Crick', '2iL PABPC1', 'C4_Benthyl', 'C4_Proteintech']
)
fig.map_dataframe(sns.stripplot, x='Condition', y='% significant k-mers', hue='Kmer group', dodge=True, color='grey')
fig.savefig(f'{outpath}/Perc_SignificantKmers.pdf', bbox_inches='tight')

# %%
DfCountGroups
# Out:
#                                                  File  N significant total  \
# 0            DOX_C1_Crick1_5mer_distribution_UTR3.tsv                   35
# 1            DOX_C1_Crick2_5mer_distribution_UTR3.tsv                   37
# 2         DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   27
# 3         DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   28
# 4     DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   36
# 5     DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   30
# 6             KO_C1_Crick1_5mer_distribution_UTR3.tsv                   32
# 7             KO_C1_Crick2_5mer_distribution_UTR3.tsv                   27
# 8          KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   26
# 9          KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   35
# 10     KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   38
# 11     KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   31
# 12  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_...                   27
# 13           DOX_C1_Crick1_5mer_distribution_UTR3.tsv                   35
# 14           DOX_C1_Crick2_5mer_distribution_UTR3.tsv                   37
# 15        DOX_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   27
# 16        DOX_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   28
# 17    DOX_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   36
# 18    DOX_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   30
# 19            KO_C1_Crick1_5mer_distribution_UTR3.tsv                   32
# 20            KO_C1_Crick2_5mer_distribution_UTR3.tsv                   27
# 21         KO_C4_Benthyl_1_5mer_distribution_UTR3.tsv                   26
# 22         KO_C4_Benthyl_2_5mer_distribution_UTR3.tsv                   35
# 23     KO_C4_Proteintech_1_5mer_distribution_UTR3.tsv                   38
# 24     KO_C4_Proteintech_2_5mer_distribution_UTR3.tsv                   31
# 25  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39_...                   27
#
#    Kmer group  N Significant kmers  % significant k-mers  \
# 0      A-rich                    0              0.000000
# 1      A-rich                    1              2.702703
# 2      A-rich                    0              0.000000
# 3      A-rich                    6             21.428571
# 4      A-rich                   13             36.111111
# 5      A-rich                   12             40.000000
# 6      A-rich                    2              6.250000
# 7      A-rich                    1              3.703704
# 8      A-rich                    2              7.692308
# 9      A-rich                    3              8.571429
# 10     A-rich                   15             39.473684
# 11     A-rich                    9             29.032258
# 12     A-rich                    2              7.407407
# 13     U-rich                   35            100.000000
# 14     U-rich                   36             97.297297
# 15     U-rich                   27            100.000000
# 16     U-rich                   21             75.000000
# 17     U-rich                   23             63.888889
# 18     U-rich                   18             60.000000
# 19     U-rich                   30             93.750000
# 20     U-rich                   26             96.296296
# 21     U-rich                   22             84.615385
# 22     U-rich                   23             65.714286
# 23     U-rich                   23             60.526316
# 24     U-rich                   22             70.967742
# 25     U-rich                   25             92.592593
#
#                                            Sample Condition      Experiment
# 0                                   DOX_C1_Crick1       DOX        C1_Crick
# 1                                   DOX_C1_Crick2       DOX        C1_Crick
# 2                                DOX_C4_Benthyl_1       DOX      C4_Benthyl
# 3                                DOX_C4_Benthyl_2       DOX      C4_Benthyl
# 4                            DOX_C4_Proteintech_1       DOX  C4_Proteintech
# 5                            DOX_C4_Proteintech_2       DOX  C4_Proteintech
# 6                                    KO_C1_Crick1        KO        C1_Crick
# 7                                    KO_C1_Crick2        KO        C1_Crick
# 8                                 KO_C4_Benthyl_1        KO      C4_Benthyl
# 9                                 KO_C4_Benthyl_2        KO      C4_Benthyl
# 10                            KO_C4_Proteintech_1        KO  C4_Proteintech
# 11                            KO_C4_Proteintech_2        KO  C4_Proteintech
# 12  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39       DOX      2iL PABPC1
# 13                                  DOX_C1_Crick1       DOX        C1_Crick
# 14                                  DOX_C1_Crick2       DOX        C1_Crick
# 15                               DOX_C4_Benthyl_1       DOX      C4_Benthyl
# 16                               DOX_C4_Benthyl_2       DOX      C4_Benthyl
# 17                           DOX_C4_Proteintech_1       DOX  C4_Proteintech
# 18                           DOX_C4_Proteintech_2       DOX  C4_Proteintech
# 19                                   KO_C1_Crick1        KO        C1_Crick
# 20                                   KO_C1_Crick2        KO        C1_Crick
# 21                                KO_C4_Benthyl_1        KO      C4_Benthyl
# 22                                KO_C4_Benthyl_2        KO      C4_Benthyl
# 23                            KO_C4_Proteintech_1        KO  C4_Proteintech
# 24                            KO_C4_Proteintech_2        KO  C4_Proteintech
# 25  PABPC1_ESC_DKO_doxGFPLin28A_grouped_cdna_mm39       DOX      2iL PABPC1
